# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("hyperparams/anomaly_table.csv", sep='\t')
print("Number of rows and columns:", df.shape)
# df.head()
# Out:
# Number of rows and columns: (23, 7)

# %%
df[['batch_size','loss','val_loss']][0:5].plot.line(x='batch_size', figsize=(12, 7))
df[['epochs','loss','val_loss']][5:9].plot.line(x='epochs', figsize=(12, 7))
df[['units','loss','val_loss']][9:14].plot.line(x='units', figsize=(12, 7))
df[['look_back','loss','val_loss']][14:19].plot.line(x='look_back', figsize=(12, 7))
df[['layers','loss','val_loss']][19:].plot.line(x='layers', figsize=(12, 7))
# Out:
# <AxesSubplot:xlabel='layers'>
