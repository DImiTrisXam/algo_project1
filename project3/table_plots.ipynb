# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("hyperparams/forecast_table.csv", sep='\t')
print("Number of rows and columns:", df.shape)
df.head()
# Out:
# Number of rows and columns: (24, 7)
#    layers  units  epochs  batch_size  look_back    loss  val_loss
# 0       4     50      10           1         60  0.0009    0.0053
# 1       4     50      10          16         60  0.0016    0.0008
# 2       4     50      10          32         60  0.0022    0.0021
# 3       4     50      10          64         60  0.0029    0.0042
# 4       4     50      10         128         60  0.0030    0.0012

# %%
df[['batch_size','loss','val_loss']][0:5].plot.line(x='batch_size', figsize=(12, 7))
df[['epochs','loss','val_loss']][5:9].plot.line(x='epochs', figsize=(12, 7))
df[['layers','loss','val_loss']][9:13].plot.line(x='layers', figsize=(12, 7))
df[['units','loss','val_loss']][13:19].plot.line(x='units', figsize=(12, 7))
df[['look_back','loss','val_loss']][19:].plot.line(x='look_back', figsize=(12, 7))
# Out:
# <AxesSubplot:xlabel='look_back'>
